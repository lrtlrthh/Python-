# %% [markdown]
# # 自然语言处理概述

# %% [markdown]
# ## 1.1 什么是自然语言处理？

# %% [markdown]
# ### 1.1.1 课程导入：身边的 AI 技术
#
# 请大家思考一个问题：
#
#
# 我们用很多软件的时候都会发现有一个"猜你喜欢"的功能，为什么他猜的内容这么准确？
#
#
# <div class='insertContainerBox column'>
# <div class='insertItem' align=center><img src="http://files.momodel.cn/hv/f5b993f8a5ab48cc9dc5047cbb0a3dd5.png" width="400px"/></div>
# </div>
#
#
# 当你打开购物APP，为什么"猜你喜欢"推荐的商品如此准确？
# 当你使用语音助手时，它为什么能听懂你说的话？
# 当你在抖音看视频时，为什么字幕能自动生成？
#
# 这些神奇功能背后，都有一个共同的技术——**自然语言处理**！

# %% [markdown]
# ### 1.1.2 定义
#
# **自然语言处理**（Natural Language Processing, NLP）是人工智能的一个重要分支，专注于让计算机能够理解、处理和生成人类语言。
#
# **核心任务包括：**
# - **理解（Understand）：** 让计算机读懂人类语言
# - **处理（Process）：** 对语言进行分析和加工
# - **生成（Generate）：** 让计算机输出自然语言

# %% [markdown]
# ### 1.1.3 生活中的 NLP 应用
#
# **让我们一起来列举身边的 NLP 应用：**
#
# 1. **智能手机输入法**：自动纠错、词语预测
# 2. **语音助手**：Siri、小爱同学、天猫精灵
# 3. **智能客服**：银行、电商的24小时在线客服
# 4. **机器翻译**：Google翻译、百度翻译
# 5. **搜索引擎**：百度、Google的智能搜索
# 6. **社交媒体**：微博、微信的内容推荐和审核
# 7. **智能推荐**：淘宝、抖音的个性化推荐

# %% [markdown]
# ### 1.1.4 NLP的三个核心能力
#
# 1. 能力一：听懂（语言理解）
#
# **例子：** 朋友说："我昨天买了个新手机，拍照效果超棒！"
#
# **计算机需要：**
# - 识别词语：手机、拍照、效果、超棒
# - 理解含义：朋友在分享买手机的喜悦
# - 抓住重点：手机拍照功能很好

# %% [markdown]
# 2. 能力二：思考（信息处理）
#
# **计算机需要分析：**
# - 什么品牌的手机？
# - 拍照好在哪里？
# - 用户满意度如何？

# %% [markdown]
# 3. 能力三：回答（语言生成）
#
# **可能的回应：**
# - "真的吗？是什么牌子的？"
# - "拍照好就行，我也准备换个手机"
# - "多少钱买的？推荐一下"

# %% [markdown]
# ### 1.1.5 你的第一个NLP程序

# %% [markdown]
# 接下来我们看一下NLP的简单实际应用，给一句中文进行分词。
#
# 我们使用```jieba```库，这是 Python 中最常用的中文分词库，专门用于把连续的中文文本拆分成有意义的词语（比如把 “自然语言处理” 拆成 “自然 / 语言 / 处理”），是中文自然语言处理（NLP）的基础工具之一。

# %%
# 用jieba进行中文分词
import jieba

# 定义要处理的文本
print(f"我们要处理的文本是：{text}")
print(f"文本的字符数：{len(text)}")

# 用jieba进行分词
words = jieba.lcut(text)  # lcut直接返回列表

print(f"\n分词后的词语：{words}")
print(f"词语数量：{len(words)}")

print("\n恭喜！你已经用jieba完成了中文分词！")
