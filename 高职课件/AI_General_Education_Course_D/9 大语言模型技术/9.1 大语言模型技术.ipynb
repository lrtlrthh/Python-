# %% [markdown]
# # 大语言模型技术

# %% [markdown]
# ## 1. 大语言模型的局限和优化

# %% [markdown]
# 大家应该都使用过大语言模型应用，比如说：ChatGPT、文心一言、Kimi、豆包等等。
#
#
#
# <div class='insertContainerBox column'>
# <div class='insertItem' align=center><img src="https://imgbed.momodel.cn//img/202412251402005.png" width="800px"/></div>
# </div>
#
#
# 这些备受瞩目的大型语言模型，在各个测评和宣传的时候，都说效果非常的好甚至在一些方面能够赶超人类。。

# %% [markdown]
# 比如在MMLU测试时，GPT-3、GPT3.5、GPT-4已经超过人类平均水平，GPT-o1甚至超过了人类专家水平。
# <div class='insertItem' align=center><img src="https://imgbed.momodel.cn//img/202412311552684.png" width="1200px"/></div>
# 来源：https://s10251.pcdn.co/wp-content/uploads/2024/09/2024-Alan-D-Thompson-GPT-4-5-MMLU-Rev-C.png
#
# MMLU (Massive Multitask Language Understanding) 是一个用于评估语言模型在多种任务上的理解能力的基准测试。
# 它包含了多个子任务，旨在测量模型在不同领域和主题上的表现，包括但不限于：常识推理、数学、科学、文学、社会科学。

# %% [markdown]
# 在很多考试中大模型也超过了人类水平
# <div class='insertItem' align=center><img src="https://imgbed.momodel.cn//img/202412261252410.png" width="1200px"/></div>
# 数字表示百分位数，50表示平均数，但不一定是某些测试的平均数。
# 来源： Alan D. Thompson, 2023年3月. https://lifearchitect.ai/iq-testing-ai/
#
# 1. SAT(Scholastic Assessment Test)：美国大学的入学申请。它评估学生在阅读、写作和数学方面的能力。
#
# 2. Economics: George Mason University Economics 321 Midterm by Prof Caplan：乔治梅森大学（George Mason University）经济学课程的中期考试。
#
# 3. Maths: Grade-school maths (GSM8K)：Grade-school maths (GSM8K) ：是一个数据集，包含与小学数学相关的问题，通常用于训练和评估机器学习模型在解决基础数学问题上的能力。
#
# 4. Law: Uniform Bar Exam (MBE + MEE + MPT)：Uniform Bar Exam (UBE) 是一项在多个州使用的律师资格考试
# 5. Medicine: Medical Knowledge Self-Assessment Program：是为医学专业人员设计的自我评估工具，帮助医生评估其医学知识水平并准备执业考试。
#
# 6. Biology: USA Biolympiad (USABO) Semifinal Exam 2020：USA Biolympiad (USABO) ：是针对高中生的生物学竞赛，旨在选拔优秀学生参加国际生物奥林匹克竞赛。2020 年的半决赛考试是该竞赛的一部分。
#
# 7. Wine tasting: Advanced Sommelier (theory knowledge)：葡萄酒品鉴领域的高级认证，通常涵盖关于葡萄酒的理论知识、品尝技巧、配餐建议等内容。
#
# 8. AllQ benchmark (MMLU)：一个用于评估语言模型理解和回答各种问题的基准数据集，涵盖多个领域和主题。
#
# 9. Commonsense inference (HellaSwag)：HellaSwag 是一个数据集，用于评估机器学习模型的常识推理能力，特别是在自然语言处理任务中，测试模型如何理解和生成符合常识的文本。
#
# 10. Knowledge, commonsense (WinoGrande)：WinoGrande 是一个用于测试模型对常识和背景知识理解能力的数据集，尤其关注代词消歧义和上下文理解。

# %% [markdown]
# ### 1.1 大语言的模型的局限

# %% [markdown]
# 1. 时效性差
#
#    AI 大语言模型生成的**知识来自训练时接触到的数据**，无法提供未知信息或新的发现。
#
#    举例：如果您询问关于一项最新科学研究的问题，模型可能无法提供相关信息，因为它的知识截止日期通常在训练数据截止日期之前。
#    如下图：
#    GPT-4
# <div class='insertContainerBox column'>
# <div class='insertItem' align=center><img src="https://imgbed.momodel.cn//img/202412311609746.png" width="1100px"/></div>
# </div>
# 钉钉小助手
# <div class='insertContainerBox column'>
# <div class='insertItem' align=center><img src="https://imgbed.momodel.cn//img/202412311453245.png" width="1100px"/></div>
# </div>

# %% [markdown]
# 2. 上下文记忆有限
#
#     上下文记忆是指模型在生成文本时能理解并关联之前的内容。这对于对话系统、长篇文档生成和信息总结等任务至关重要。
#
#    上下文记忆问题可能是由于模型在处理超长文本时遇到了**字节长度限制或者信息丢失**的情况。
#
#     这可能会导致模型在较长的对话或文本中失去一些先前的上下文信息。

# %% [markdown]
# 比如我们看一下下面的例子，我们赋予大模型角色，让他帮我们生成小说。
#
#
# <div class="insertContainerBox" align=center>
# <video src="https://files.momodel.cn/zju_ding/1%E6%9C%889%E6%97%A5.mp4" controls="controls" width="100%"/>
# </div>

# %% [markdown]
#  3. 通而不专
#
#     训练数据的局限性。大语言模型通常在海量的**通用领域数据**上训练,而特定**专业领域的数据**相对**较少**。
#
#     专业术语和知识的复杂性。专业领域通常涉及复杂的概念、术语和实体之间的关系，大模型很难掌握这些深奥的专业知识。
#
#     知识的系统性和连贯性不足。大模型是基于概率预测下一个单词，而非基于结构化的知识库给出明确答案。

# %% [markdown]
# 4. 存在幻觉
#    由于 AI 大模型 的生成是**概率性的**，且会针对性做一些人类倾向的对齐处理，以实现让人满意的效果，以及满足一定泛化能力，
#   因此 AI 在面对没有训练过的场景，会概率性生成可能被期待的内容（**有一定讨好倾向**）。
#
#     举例：向 AI 大语言模型询问“林黛玉为什么倒拔垂杨柳？”
#
# GPT-4
# <div class='insertContainerBox column'>
# <div class='insertItem' align=center><img src="https://imgbed.momodel.cn//img/202412311610561.png" width="1000px"/></div>
# </div>
#
# 钉钉小助手-月之暗面128K
# <div class='insertContainerBox column'>
# <div class='insertItem' align=center><img src="https://imgbed.momodel.cn//img/202412311614510.png" width="1200px"/></div>
# </div>

# %% [markdown]
# 5. 无法精确字数
#
#   在让大语言模型写文章时，在 Prompt 提示词里写明需要生成 1000 字的文章，
#   但它写出来的文章字数可能是 900 字，就是很难精确刚刚好是 1000 字。
#
#   大模型无法输出准确的字数的原因是多方面的，
#   包括**数据噪声、过拟合、基于概率统计的预测方法、设计限制、输入文本长度限制以及幻觉问题**等。
#
#   这些因素共同作用，导致大模型在处理特定任务时，无法精确控制生成内容的字数。

# %% [markdown]
# 6. 数学水平不稳
#
#     GPT-4 在表达数学概念、解决数学问题、应用量化推理、面对需要数学思维和模型构建的问题等方面，有了很大进展。
# 但粗心大意，心直口快、嘴比脑子快
# 本质是语言生成模型，持续预测下一个字符，逻辑严谨性不足
#
#     <div class='insertContainerBox column'>
#     <div class='insertItem' align=center><img src="https://imgbed.momodel.cn//img/202412201129020.png" width="600px"/></div>
#     </div>

# %% [markdown]
# 求是小学组织去距离 180 公里的博物馆春游，全班同学 8:00 从学校坐大巴车出发。班主任老师因为有事情，8:10 自己自驾小车以大巴车快 1/3 的速度追赶，结果比大巴车提前 20 分钟到。问：
# （1）大巴和小车的速度各是多少？
# （2）班主任老师追上大巴的地点距离博物馆还有多远？
#
# <div class="insertContainerBox" align=center>
# <video src="https://imgbed.momodel.cn//img/202412201419148.mp4" controls="controls" width="50%"/>
# </div>
#
# <div class="insertContainerBox" align=center>
# <video src="https://imgbed.momodel.cn//img/202412201421900.mp4" controls="controls" width="50%"/>
# </div>

# %% [markdown]
# ### 1.2 优化大模型的三个路径

# %% [markdown]
# 三种优化方法：
# <div class='insertContainerBox column'>
# <div class='insertItem' align=center><img src="https://imgbed.momodel.cn//img/202412241419475.png" width="1300px"/></div>
# </div>

# %% [markdown]
# 优化流程：
# <div class='insertContainerBox column'>
# <div class='insertItem' align=center><img src="https://imgbed.momodel.cn//img/202412201732278.png" width="1300px"/></div>
# </div>

# %% [markdown]
# ## 2. 提示词工程

# %% [markdown]
# ### 2.1 什么是提示词
#
# 提示词 Prompt 是**一种短文本字符串，用于指导语言模型生成响应**。
#
# Prompt 通常翻译成提示文本，是一段文本或一个问题，
#
# 具体形式取决于用户的需求和应用场景，
#
# 作用是**引导生成式 AI 大模型产生预期的回答或反应**。

# %% [markdown]
# 比如下图——Prompt 效果示例：
#
#
# <div class='insertContainerBox column'>
# <div class='insertItem' align=center><img src="https://imgbed.momodel.cn//img/202412311618350.png" width="1300px"/></div>
# </div>

# %% [markdown]
# Prompt 可以包含任务相关的信息和上下文，以帮助模型更好地理解要求并生成正确的输出。
#
# 对于具有较强自然语言理解、生成能力，能够实现多样化任务处理的大语言模型（LLM）来说，
#
# 一个好的 Prompt 极大地决定了其能力的上限与下限，并会**影响其输出文本的内容、风格和整体质量**。

# %% [markdown]
# 举个例子：
# 如果我们把 AI 模型比作一名员工，Prompt 就相当于给员工的具体指令。
# 指令的明确性和详细性决定了模型的输出效果。
#
# <div class='insertContainerBox column'>
# <div class='insertItem' align=center><img src="https://mo-app.momodel.cn/card_unit_new/32/prompt-2.png" width="1100px"/></div>
# </div>

# %% [markdown]
# 如何去使用 Prompt，以充分发挥 LLM 的性能？
# 设计 Prompt 有两个关键原则：
# 1. 编写清晰、具体的指令
# 2. 给予模型充足思考时间。
#
# 掌握这两点，对创建可靠的语言模型交互尤为重要。

# %% [markdown]
# ### 2.2 Prompt 常见作用
# | 作用               | 描述                                                         | 案例               |
# |------------------|------------------------------------------------------------|--------------------|
# | 引导模型输出       | 通过 prompt 设计引导 AI 模型生成特定信息或行为                         | 对话系统           |
# | 改善交互体验       | 设计用户友好的 prompt 以提升与 AI 系统的交互体验                     | 角色对话           |
# | 指导模型任务       | 使用 prompt 作为示例输入，帮助模型学习特定任务                       | 医疗诊断           |
# | 进行一定微调       | 通过 prompt 微调预训练模型，使其适应特定领域或任务                   | 法律、金融应用     |
# | 控制生成内容       | 调整 prompt 来控制 AI 生成内容的风格、主题和格式                       | 生成 json 格式       |
# | 提高可解释度       | 利用 prompt 分析模型反应，提高 AI 模型的透明度和可解释性               | 给出思考过程       |
# | 提升安全性和道德可靠性 | 设计 prompt 以防止生成有害内容，确保 AI 系统的道德使用               | 敏感词回避         |
# | 降低一定成本       | 设计 prompt 提供较稳定的效果，减少一定的 token 消耗                     |                    |
#
#
# - 引导模型输出：
#        1.请以正式的风格撰写一封邀请函。
#        2.描述一下未来十年的科技发展趋势。
#
# - 改善交互体验：
#       1.你现在是一名客服代表，请用亲切的语言回答我的问题。
#       2.为了让我更好地理解，请用简单的语言解释这个概念。
#
# - 指导模型任务：
#        1.请根据以下病例信息，提供可能的医疗诊断：症状包括...，病史包括...。
#        2.参考以下建筑设计图纸，生成一份详细的施工计划。

# %% [markdown]
# ### 2.3 提示词工程

# %% [markdown]
# - 提示词工程就是一种人与机器交互的程序语言。
#
# <div class='insertContainerBox column'>
# <div class='insertItem' align=center><img src="https://imgbed.momodel.cn//img/202412210927261.png" width="800px"/></div>
# </div>

# %% [markdown]
# 提示词工程大赛
#
# <div class='insertContainerBox column'>
# <div class='insertItem' align=center><img src="https://imgbed.momodel.cn//img/202412210942527.png" width="1100px"/></div>
# </div>
#
# 新加坡大赛的决赛赛题：
# <div class='insertContainerBox column'>
# <div class='insertItem' align=center><img src="https://imgbed.momodel.cn//img/202412271605285.png" width="1100px"/></div>
# </div>
#
#
#
# 参考链接：https://minicolee.medium.com/how-govtech-designed-the-worlds-first-gpt-4-live-tournament-6249cfc8aa97

# %% [markdown]
# ## 3. 提示词技巧

# %% [markdown]
# ### 3.1 提示词工程的使用模式
#
#
#
# <div class='insertContainerBox column'>
# <div class='insertItem' align=center><img src="https://imgbed.momodel.cn//img/202412241423002.png" width="1000px"/></div>
# </div>

# %% [markdown]
# ### 3.2 提示词技巧

# %% [markdown]
# #### 3.2.1 零样本提示
#
# 零样本提示（Zero-Shot Prompting）是一种自然语言处理技术，可以让计算机模型根据提示或指令进行任务处理。
#
# 传统的自然语言处理技术通常需要在大量标注数据上进行有监督的训练，以便模型可以对特定任务或领域进行准确的预测或生成输出。
# 相比之下，零样本提示的方法更为灵活和通用，因为它不需要针对每个新任务或领域都进行专门的训练。
# 相反，它利用 LLM 的强大预训练知识，通过最小化的示例输入，实现对复杂任务的快速适应和高效处理。

# %% [markdown]
# 举个例子，描述某部电影的故事情节，
# 如下图，可以看到它可以生成一个关于该情节的摘要，而不需要进行电影相关的专门训练。
#
#
# <div class='insertContainerBox column'>
# <div class='insertItem' align=center><img src="https://imgbed.momodel.cn//img/202501062059170.png" width="1000px"/></div>
# </div>

# %% [markdown]
# 有两点需要注意：
#
# • Prompt 中不包含任何示例。
#
# • LLM 完全依赖其预训练的知识来理解问题并回答它。

# %% [markdown]
# 但这个技术并不是没有缺点的：
#
# 1. 零样本提示依赖于预训练的语言模型，这些模型可能会受到训练数据集的限制和偏见。比如在使用文心一言的时候，它常常会在一些投资领域，使用男性的「他」，而不是女性的「她」。那是因为训练文心一言的数据里，提到金融投资领域的内容，多为男性。
#
# 2. 尽管零样本提示不需要为每个任务训练单独的模型，但为了获得最佳性能，它需要大量的样本数据进行微调。像文心一言就是一个例子，它的样本数量是过千亿。
#
# 3. 由于零样本提示的灵活性和通用性，它的输出有时可能不够准确，或不符合预期。这可能需要对模型进行进一步的微调或添加更多的提示文本来纠正。

# %% [markdown]
# #### 3.2.2 少样本提示
# 少样本提示（Few-Shot Prompting）指的是训练机器学习模型时只使用极少量的标注样本。
#
# 它的目标是使机器学习模型在只有少量标注样本的情况下也能达到良好的性能。
# 实际上就是我们可以给模型一些示例，从而让模型返回更符合我们需求的答案。

# %% [markdown]
# 让我们看下面这个例子，在这个例子中，任务是在句子中正确使用一个新词。
# 提示词：
# ```
# “whatpu”是坦桑尼亚的一种小型毛茸茸的动物。一个使用whatpu这个词的句子的例子是：
# 我们在非洲旅行时看到了这些非常可爱的whatpus。
# “farduddle”是指快速跳上跳下。一个使用farduddle这个词的句子的例子是：
# ```
# 输出：
#
#
# <div class='insertContainerBox column'>
# <div class='insertItem' align=center><img src="https://imgbed.momodel.cn//img/202501062134238.png" width="1000px"/></div>
# </div>

# %% [markdown]
# 少样本提示的局限性：
# 尽管少样本提示很有用，但它依然存在很大的局限性。
# 其中，最大的局限性就是它依赖于所提供示例的质量和多样性。

# %% [markdown]
# ### 3.3 提示词框架

# %% [markdown]
# #### 3.3.1 ICIO 框架
#
# ICIO 框架由 Elavis Saravia 提出并发布在 Github,该框架主要包括以下四个部分
# *   Instruction(必须)：指令，即你希望模型执行的具体任务。
# *   Context(选填)：背景信息，或者说是上下文信息，这可以引导模型做出更好的反应。
# *   Input Data(选填)：输入数据，告知模型需要处理的数据。
# *   Output Indicator(选填)：输出指示器，告知模型我们要输出的类型或格式。
#
# ICIO 框架虽然简单，但是非常实用，大部分场景都能使用这个框架拿到一个非常不错的返回。
#
# 我们来一个简单的例子，这是一个程序员比较容易理解的提示词案例：
# ```
# Instruction（任务）：请编写一个 Python 函数，该函数能够接受一个字符串列表作为输入，并返回一个新的列表，其中包含所有字符串长度大于 5 的元素。
#
# Context（背景）：这个函数将被用于数据清洗过程，我们需要过滤掉那些不符合特定长度要求的字符串，以便后续的文本分析工作。这个函数将被集成到我们的数据分析工具中，因此需要确保它具有良好的性能和稳定性。
#
# Input Data（输入数据）：["hello", "world", "Moonshot", "AI", "technology"]
#
# Output Indicator（输出格式）：函数应返回一个新的列表，其中只包含长度大于5的字符串。例如，对于上述输入数据，期望的输出应该是["Moonshot", "technology"]。
#
# ```

# %% [markdown]
# #### 3.3.2 CRISPE 框架
#
# *   CR:Capacity and Role(能力与角色)：你希望大模型扮演怎样的角色。
# *   I:Insight(背景)：背景信息和上下文。
# *   S:Statement(指令)：你希望大模型做什么。
# *   P:Personality(格式)：你希望大模型以什么风格或方式回答你。
# *   E:Experiment(尝试)：要求大模型为你提供多个答案。
#
# 来一个程序员工作中常见场景的示例：
# ```
# Capacity and Role（角色）：你是一位经验丰富的软件开发顾问，专门帮助解决复杂的编程问题。
#
# Insight（背景）：我们正在开发一个电子商务平台，需要处理大量的用户交易数据。我们的目标是优化数据库查询性能，以减少页面加载时间并提高用户体验。
#
# Statement（指令）：请提供一个优化 SQL 查询性能的策略，特别是针对高并发环境下的读操作。
#
# Personality（格式）：请以简洁明了的技术文档格式提供解决方案，包括关键点和代码示例。
#
# Experiment（尝试）：如果你能提供多种策略，我们将非常感激，这样我们可以评估不同方法的优劣。
#
# ```

# %% [markdown]
# #### 3.3.3  CO-STAR 框架
#  由新加坡政府科技局（GovTech）组织的首届 GPT-4 提示工程大赛中一举夺冠的 Sheila Teo，所使用的提示词框架 CO-STAR：
# <div class='insertContainerBox column'>
# <div class='insertItem' align=center><img src="https://imgbed.momodel.cn//img/202412241455749.png" width="1000px"/></div>
# </div>
#
# - Context-上下文 ： 为任务提供背景信息 。通过为大语言模型（LLM）提供详细的背景信息，可以帮助它精确理解讨论的具体场景，确保提供的反馈具有相关性。
# - Objective-目标 ： 明确你要求大语言模型完成的任务 。清晰地界定任务目标，可以使大语言模型更专注地调整其回应，以实现这一具体目标。
# - Style-风格 ： 明确你期望的写作风格 。你可以指定一个特定的著名人物或某个行业专家的写作风格，如商业分析师或 CEO。这将指导大语言模型以一种符合你需求的方式和词汇选择进行回应。
# - Tone-语气 ： 设置回应的情感调 。设定适当的语气，确保大语言模型的回应能够与预期的情感或情绪背景相协调。可能的语气包括正式、幽默、富有同情心等。
# - Audience-受众 ： 识别目标受众 。针对特定受众定制大语言模型的回应，无论是领域内的专家、初学者还是儿童，都能确保内容在特定上下文中适当且容易理解。
# - Response-响应 ： 规定输出的格式 。确定输出格式是为了确保大语言模型按照你的具体需求进行输出，便于执行下游任务。常见的格式包括列表、JSON 格式的数据、专业报告等。对于大部分需要程序化处理大语言模型输出的应用来说，JSON 格式是理想的选择。

# %% [markdown]
# 我们来看一个案例：
# ```
# Context（上下文）：你是一位经验丰富的软件工程师，目前正参与一个敏捷开发项目，该项目旨在为一家金融科技公司开发一个风险评估工具。这个工具需要集成到现有的系统中，并与多个数据源交互，以实时计算风险评分。
#
# Objective（目标）：编写一个函数，该函数能够从多个数据源中提取数据，并计算出一个综合的风险评分。这个函数需要能够处理异常情况，并确保数据的一致性和准确性。
#
# Style（风格）：请以清晰、简洁的技术文档风格提供解决方案，包括伪代码或实际代码示例，以及必要的注释。
#
# Tone（语调）：保持专业和事实性的语调，确保内容适合技术团队内部交流。
#
# Audience（受众）：这个函数将由项目团队中的其他开发人员使用，他们具有不同的技术背景，因此需要确保代码易于理解和维护。
#
# Response（回应）：请提供一个完整的函数实现，包括输入参数、处理逻辑和返回值。如果可能，请提供单元测试用例，以验证函数的正确性。
# ```
