# %% [markdown]
# # AIGC 基础与应用

# %% [markdown]
# ## 1. AIGC 简介

# %% [markdown]
# **AIGC（Artificial Intelligence Generated Content，人工智能生成内容）** 是生成式人工智能的统称，指利用 AI 技术自动生成文本、图像、音频、视频等内容的技术。
#
# **核心特征**
# - **自动化生成**：无需人工逐字编写或绘制。
# - **多模态输出**：支持跨文本、图像、音频的联合生成。
# - **高效迭代**：基于反馈快速优化生成结果。

# %% [markdown]
# **技术分类**
#
# | 生成内容类型 | 代表技术/模型         | 典型应用场景               |
# |--------------|----------------------|--------------------------|
# | **文本**     | ChatGPT、文心一言、DeepSeek       | 新闻写作、代码生成、客服对话 |
# | **图像**     | Midjourney、Stable Diffusion、文心一格、通义万相 | 艺术创作、广告设计、游戏素材 |
# | **音频**     | WaveNet、网易天音、天谱乐      | 语音合成、音乐生成         |
# | **视频**     | Runway ML、Sora、剪映      | 短视频生成、电影特效       |

# %% [markdown]
# **文本生成示例**
# 提示词：用 Python 写一个快速排序算法
# <div class='insertContainerBox column'>
# <div class='insertItem' align=center><img src="https://imgbed.momodel.cn//img/dingding/202502111640292.png" width="1000px"/></div>
# </div>

# %% [markdown]
# **图像生成示例**
#
# <div class='insertContainerBox column'>
# <div class='insertItem' align=center><img src="https://imgbed.momodel.cn//img/dingding/202502111643645.png" width="1100px"/></div>
# </div>

# %% [markdown]
# **音频生成示例**
#
# 提示词：以欢欢喜喜的庆典为背景，融合发财暴富的梦想与好运连连的祝愿，创作一首节奏明快、充满正能量的吉祥之歌。
#
#
# <div class="insertContainerBox" align=center>
# <video src="https://imgbed.momodel.cn//img/dingding/202502111603078.mp4" controls="controls" width="100%"/>
# </div>

# %% [markdown]
# **视频生成示例**
#
#
# <div class="insertContainerBox" align=center>
# <video src="https://imgbed.momodel.cn//img/dingding/202502111707745.mp4" controls="controls" width="100%"/>
# </div>

# %% [markdown]
# ## 2. AIGC 发展历程

# %% [markdown]
# ### 2.1 PGC → UGC → AIGC

# %% [markdown]
# 在数字内容爆炸式增长的今天，内容创作模式经历了从专业生产内容（PGC）到用户生产内容（UGC），再到人工智能生成内容（AIGC）的演变。
# 这一历程不仅反映了技术进步的轨迹，也揭示了内容创作和消费方式的深刻变革。
#
# <div class='insertContainerBox column'>
# <div align=center><img src="https://imgbed.momodel.cn//20230811140922.png" width="600px"/></div>
# </div>
#
#
# **PGC（专业生产内容）时代**
#
# - 定义：PGC（Professionally Generated Content）指由专业机构或专业人士生产的内容，通常具有较高的质量和专业性。
# - 特点：内容质量高、信息权威、更新频率稳定，但生产成本较高，内容多样性受限。
# -  代表案例
#  - 传统媒体：报纸、杂志、电视台等。
#  - 在线媒体平台：早期的新浪、网易等门户网站。
# - 影响与局限
#  - 影响：为大众提供了稳定、高质量的信息来源。
#  - 局限：内容生产门槛高，难以满足个性化、多样化的需求。
#
# **UGC（用户生产内容）时代**
#
# - 定义：UGC（User Generated Content）指由普通用户生产的内容，通常具有个性化、多样化的特点。
# - 特点：内容生产门槛低、参与度高、形式多样，但质量参差不齐。
# - 代表案例
#  - 社交媒体：微博、微信、抖音等。
#  - 视频分享平台：YouTube、B 站等。
# - 影响与变革
#  - 影响：极大地丰富了内容生态，满足了用户的个性化需求。
#  - 变革：内容创作和消费方式从单向传播转向双向互动，用户成为内容创作的重要力量。
#
# **AIGC（人工智能生成内容）时代**
#
# - 定义：AIGC（Artificial Intelligence Generated Content）指利用人工智能技术自动生成的内容，通常具有高效、个性化、可定制的特点。
# - 特点：内容生成速度快、质量可控、可大规模定制，但依赖于算法和数据。
# - 技术基础与应用
#  - 技术基础：深度学习、自然语言处理、生成对抗网络等。
#  - 应用：文本生成（新闻报道、广告文案）、图像生成（艺术画作、医学影像）、音频生成（语音合成、音乐创作）等。
# - 发展趋势与挑战
#  - 发展趋势：技术不断进步，生成内容的质量和多样性不断提高。
# - 挑战：版权问题、内容真实性验证、伦理道德问题等。

# %% [markdown]
# ### 2.2 AIGC 发展三阶段

# %% [markdown]
# **早期萌芽阶段 (1950-1990s)**
#
# 受限于当时的科技水平，AIGC 仅限于小范围实验。
#
# **1957 年**，历史上第一首由计算机创作的音乐作品——弦乐四重奏《依利亚克组曲 ( Illiac Suite)》出现。
#
# **1966 年**，世界第一个可人机对话的机器人“伊莉莎 ( Eliza)”诞生。
#
# **80 年代末至 90 年代中**由于高昂的系统成本无法带来可观的商业变现，
# 各国政府减少了在人工智能领域的投入，AIGC 没有取得重大突破。

# %% [markdown]
# 我们运行下面的代码，听一下第一首由计算机创作的音乐作品。

# %%
from IPython.display import Audio,display
sound_file = 'https://imgbed.momodel.cn/202411071014953.mp3'
display(Audio(sound_file))

# %% [markdown]
# **沉淀积累阶段 (1990s-2010s) **
#
# AIGC 逐渐从实验性向实用性转变。
#
# **2006 年**，深度学习算法取得重大突破，互联网为各类人工智能算法提供了海量训练数据，使人工智能发展取得了显著的进步。
#
# **2012 年**，微软公开展示了一个全自动同声传译系统，基于深层神经网络 ( Deep NeuralNetwork,DNN ) 可以自动将英文演讲者的内容通过语音识别、语言翻译、语音合成等技术生成中文语音。

# %% [markdown]
# **快速发展阶段(2010s-至今)**
#
# AIGC 迎来了新时代。
# 自 **2014 年**起，随着以生成式对抗网络 ( Generative Adversarial Network, GAN) 为代表的深度学习算法的提出和迭代更新，生成内容百花齐放，效果逐渐逼真直至人类难以分辨。
#
# **2017 年**，微软人工智能少女“小冰”推出了世界首部 100% 由人工智能创作的诗集《阳光失了玻璃窗》。
#
#
# <div class='insertContainerBox column'>
# <div align=center><img src="https://imgbed.momodel.cn//20230828152622.png" width="400px"/></div>
# </div>
#
#
# **《用别人的心》**
# 他们的墓碑时候
# 我静悄悄的（地）顺着太阳一样
# 把全世界从没有了解的开始
# 有人说我的思想
# 他们的墓碑时候
# 你为甚在梦中做梦
# 用别人的心
# 又看到了好梦月

# %% [markdown]
# **2021** 年，OpenAI 推出了 DALL-E ，并于一年后推出了升级版本 DALL-E 2。
#
# 主要应用于文本与图像的交互生成内容。
#
# 用户只需输入简短的描述性文字，DALL-E 2 即可创作出相应极高质量的卡通、写实、抽象等风格的绘画作品。

# %% [markdown]
# <table>
# <tr>
#     <td><font size=5px>An astronaut riding a horse <br>in a photorealistic style</font></td>
#     <td><div align=center><img src="https://imgbed.momodel.cn//20230811150049.png" width="400px"/></div></td>
# </tr>
# </table>

# %% [markdown]
#
# **2022** 年，OpenAI 公布了一个通过由 GPT-3.5 驱动的全新对话式 AI 应用 ChatGPT。
#
# 这一应用引起了公众的广泛关注，AIGC 领域获得了空前的关注度。
#
# **2024年**，DeepSeek 推出 **DeepSeek-V2**，通过混合专家模型（MoE）显著降低推理成本，被誉为“AI 界的拼多多”。
#
# **2025年**：DeepSeek 发布 **DeepSeek-R1**，在复杂逻辑推理任务中比肩 OpenAI 顶级模型，但成本仅为后者的 1%。
#
# AIGC 的发展从实验室走向日常生活，DeepSeek 等中国企业的崛起证明了开源模型的强大潜力。未来，AI 不仅是工具，更是学习和创造伙伴。

# %% [markdown]
# ## 3. 生成式 AI 的应用场景
#
# 生成式 AI 的应用潜力远不止于单纯的内容生成，它们能够以前所未有的方式帮助我们创造多样化的内容形式，包括但不限于精美的文本、栩栩如生的图片以及引人入胜的视频。
#
# 更重要的是，这些强大的 AI 具备极高的可塑性和适应性，能够无缝地融入各种行业和场景之中，为不同领域带来革命性的变革。
#
#
#
# <div class='insertContainerBox column'>
# <div class='insertItem' align=center><img src="https://imgbed.momodel.cn/ai_news/202503111356352.png" width="1000px"/></div>
# </div>
#
# 图片来源：https://blog.csdn.net/CherryVxi/article/details/142856454

# %% [markdown]
# - 在工业领域，大模型可以对流程进行优化，分析海量数据，多环节实现智能化大幅提升；
#
# <div class='insertContainerBox column'>
# <div class='insertItem' align=center><img src="https://imgbed.momodel.cn//img/dingding/202502131702791.png" width="800px"/></div>
# </div>

# %% [markdown]
# - 在医疗领域，它们能辅助医生进行疾病诊断、制定个性化治疗方案，极大地提高了医疗服务的质量和精准度；
#
# <div class='insertContainerBox column'>
# <div class='insertItem' align=center><img src="https://imgbed.momodel.cn//img/dingding/202502131704692.png" width="800px"/></div>
# </div>
#
# - 金融行业中，大模型能够分析海量数据，识别风险，为客户提供更加智能化的理财建议；
# - 在教育领域，它们则能定制化教学内容，实现因材施教，让学习变得更加高效和有趣。
# …………
#
# 总之，大模型与各行各业的深度融合，正引领着我们迈向一个更加智能化、高效化的未来。

# %% [markdown]
# ## 4. 基本原理介绍

# %% [markdown]
# ### 4.1 大语言模型是“超级猜词游戏”
#
#
# - **核心任务**：根据上下文预测下一个词，生成连贯的文本。
#   - 例子 1：输入“今天天气很___”，模型可能会猜“好”或“热”。
#   - 例子 2：输入“我喜欢吃___”，模型可能会猜“苹果”或“ pizza”。
# - **为什么是“超级猜词”**：
#   - 大语言模型不仅能猜一个词，还能生成一整段话，甚至一篇文章。
#   - 它通过不断猜词，生成连贯的文本。
#   - 早期模型只能生成一个词，大语言模型可以生成一段话。
#
# <div class='insertContainerBox column'>
# <div class='insertItem' align=center><img src="https://imgbed.momodel.cn//img/dingding/202502131037565.png" width="800px"/></div>
# </div>

# %% [markdown]
# ### 4.2 核心技术

# %% [markdown]
# #### 4.2.1 神经网络：大模型的基础
#
# 神经网络是什么：
#
# - 神经网络是一种模仿人脑工作方式的计算模型。
#
# - 它由许多“小单元”（称为神经元）组成，这些神经元相互连接，共同处理信息。
#
# 神经网络的作用：
#
# - 它能够从数据中学习规律，并根据学习到的规律做出预测或决策。
#
# - 例子：输入“今天天气很___”，神经网络会猜“好”或“热”。
#
# 我们粗略了解一下神经网络的架构：
#
# <div class='insertContainerBox column'>
# <div align=center><img src="https://imgbed.momodel.cn/202501141432907.png" width="1000px"/></div>
# </div>
#
# 红色的是**输入层**，绿色的是**输出层**，蓝色的是**隐藏层**（也叫**中间层**）。
#
# 图中圆圈代表 **“神经元**”，连线代表神经元之间的连接，其中每个连接线对应不同的**权重**。
#
# 前一层（输入层）根据权重计算得到输出，同时这个输出又作为后一层（隐藏层）的输入，同理，**前一层的输出是后一层的输入**，得到最终的输出。

# %% [markdown]
# #### 4.2.2 Transformer 架构：大模型的核心
#
# **什么是 Transformer？**
#
# - 一句话定义：Transformer 是一种处理文字或序列数据的模型架构，能同时关注整个句子的所有部分，而不是按顺序逐字处理。
#
# - 核心特点：
#
#     - 并行计算（速度快）
#
#     - 自注意力机制（全局理解）
#
#     - 位置编码（保留顺序信息）

# %% [markdown]
# **Transformer 的三大法宝**
#
# 1. 自注意力（Self-Attention）
#     - **作用**：让每个字去“注意”其他字的重要性。
#     - **例子**：
#       - 句子：“我有一只猫”
#       - “猫”会关注“有”（因为“有一只猫”更合理）
#       - “它”会关注前文的“猫”（指代关系）
#
# 2.  并行计算
#     - **传统模型**：逐字处理，先处理第一个字，再处理第二个字，依此类推。像流水线，必须一步步处理。
#     - **Transformer**：一次性输入整个句子，句子中的每个字被转换为向量（字向量），所有字的向量组成一个矩阵，像工厂流水线上的多台机器，**同时处理所有字**，速度更快。
#
# 3. 位置编码（Positional Encoding）
#     - **作用**：给每个字加一个“位置标记”，告诉模型字的顺序。
#     - **例子**：
#       - “猫追狗” vs “狗追猫” → 顺序不同，意思不同。

# %% [markdown]
# 下图是 Transformer 用于中英文翻译的整体结构。
#
# <div class='insertContainerBox column'>
# <div class='insertItem' align=center><img src="https://imgbed.momodel.cn//img/dingding/202502131109120.png" width="1000px"/></div>
# </div>
#
# **Transformer 的工作原理**
#
# 1.  输入处理：拆分 + 贴标签
#     - **步骤**：
#       1. 输入句子 → 拆成字/词（如“我有一只猫” → ["我", "有", "一只", "猫"]）
#       2. 每个字转成数字（字向量）
#       3. 加位置编码（标记顺序）
#
#
# 2.  编码器（Encoder）：理解句子
#     - **目标**：理解句子的含义和关系。
#     - **结构**：
#       1. **自注意力层**：找出字之间的关系（如“猫”关注“有”）。
#       2. **前馈神经网络**：进一步提炼信息。
#     - **多层堆叠**：每层编码器逐步加深理解（如 6 层、12 层）。
#
# 3. 解码器（Decoder）：生成输出
#
#     - **目标**：生成翻译或回答。
#     - **结构**：
#       1. **自注意力层**：看已生成的部分（如生成到“I have”）。
#       2. **交叉注意力层**：从编码器提取关键信息（如“猫”对应“cat”）。
#       3. **前馈神经网络**：预测下一个字。
#     - **多层堆叠**：每层解码器逐步优化生成结果。

# %% [markdown]
# **为什么需要多个编码器和解码器？**
# 1. 逐步细化理解
#     - **底层编码器**：处理基础关系（如“猫”→“有”）。
#     - **高层编码器**：处理复杂逻辑（如“我有一只猫”表示拥有关系）。
#
#
#
# 2. 增强模型能力
#     - 层数越多，模型能学到的模式越复杂。
#     - 一般平衡在 6-12 层（如原始论文）。
#
#
# 3. 分工协作
#     - 不同层专注不同任务：
#       - 底层：处理语法和局部关系。
#       - 高层：处理语义和全局逻辑。

# %% [markdown]
# #### 4.2.3 Attention 机制：大模型的基石
#
# 什么是 Attention 机制？
#
# - **定义**：Attention 机制是模型在处理信息时，能够“注意”到输入数据的不同部分，并根据这些部分的重要性给予不同的权重的一种机制。
#
# - **类比**：就像我们在阅读文章或观看图片时，会自然而然地聚焦在最重要的内容上，Attention 机制模仿了人类在处理信息时的这种注意力分配方式。
#
# 人的注意力是有限的，无论是观看图像还是阅读文字，人们都会有选择性地关注一小部分重点内容，并忽略另一部分不重要的内容。
# 从数学的角度来说，可以将“注意力”理解为一种“权重”。
# 在理解图片或文本时，大脑会赋予对于认知有重要意义的内容高权重，赋予不重要的内容低权重。
# 在不同的上下文中专注不同的信息，这样可以帮助人们更好的理解信息，同时还能降低信息处理的难度。

# %% [markdown]
# 以下这张图可以较好地去理解注意力机制，其展示了人类在看到一幅图像时如何高效分配有限注意力资源的，
# 其中红色区域表明视觉系统更加关注的目标，
# 从图中可以看出：人们会把注意力更多的投入到人的脸部，文本的标题以及文章的首句等位置。
#
# <div class='insertContainerBox column'>
# <div align=center><img src="https://imgbed.momodel.cn//20230814142538.png" width="600px"/></div>
# </div>

# %% [markdown]
# Attention 机制的作用
#
# - **高效处理信息**：通过关注最重要的信息，模型能够更加高效地处理和理解数据。
# - **动态聚焦**：在做决策时，模型能够动态地聚焦于输入数据的某些特定区域或特征，从而提高预测的准确性。

# %% [markdown]
# #### 4.3.4  预训练和微调：大模型的学习方式
#
# 文字生成大模型通常分为两个阶段。首先是在大规模语料库上进行预训练，学习语言的一般表示。接着，模型会在特定任务或领域的较小数据集上进行微调。
# - **预训练**：
#   - 在大规模语料库上训练模型，学习语言的一般表示。
#   - 例子：模型通过阅读数百万本书，学习语法、语义和常识。
#
#
# - **微调**：
#   - 在特定任务或领域的较小数据集上进一步训练模型。
#   - 例子：在医学文本上微调模型，使其能够生成医学相关的文本。
#
#
# - **预训练和微调的意义**：
#   - 预训练让模型具备通用语言能力。
#   - 微调让模型适应特定任务。

# %% [markdown]
# ## 5. 生成式 AI 的优势与挑战

# %% [markdown]
# ### 5.1 生成式 AI 的优势
# - 内容创作效率提升:
#
#     - 自动生成文本、图像、音乐等内容，解放人力，提高创作效率。
#
#     - 例如：新闻稿撰写、产品描述生成、广告创意设计等。
#
# - 个性化内容定制:
#
#     - 根据用户偏好和需求，生成个性化内容，提升用户体验。
#
#     - 例如：个性化推荐、定制化营销文案、专属音乐播放列表等。
#
# - 突破人类想象力限制:
#
#     - 生成新颖、独特的内容，激发创意灵感，拓展人类认知边界。
#
#     - 例如：科幻小说创作、概念艺术设计、新药研发等。
#
# - 降低内容创作门槛:
#
#     - 无需专业知识和技能，即可生成高质量内容。
#
#     - 例如：普通人也能创作音乐、绘画、视频等。

# %% [markdown]
# ### 5.2 生成式 AI 的挑战

# %% [markdown]
# - 伦理道德问题:
#
#     - 生成虚假信息、恶意内容，引发社会问题。
#
#     - 例如：深度伪造、虚假新闻、网络诈骗等。
#
# 举一个实际的例子，西藏日喀则市定日县发生 6.8 级地震后，部分网友利用 AI 生成虚假灾区图片，如“被压在废墟下的小男孩”，误导公众。
#
# <div class='insertContainerBox column'>
# <div class='insertItem' align=center><img src="https://imgbed.momodel.cn/ai_news/56.gif" width="600px"/></div>
# </div>
#
#
#
#
# - 版权归属问题:
#
#     - 生成内容版权归属模糊，引发法律纠纷。
#
#     - 例如：AI 生成的艺术作品版权归属问题。
#
# - 数据偏见问题:
#
#     - 训练数据存在偏见，导致生成内容也存在偏见。
#
#     - 例如：性别歧视、种族歧视等。
#
# 清华大学的于洋教授团队设计了一套歧视审计框架，研究评估了 AI 模型的性别歧视水平，发现受测 AI 模型对于职业的性别预判倾向都为男性，存在系统性偏差。
#
# <div class='insertContainerBox column'>
# <div class='insertItem' align=center><img src="https://imgbed.momodel.cn/hv/202503111413330.png" width="600px"/></div>
# </div>
#
# 参考链接：https://baijiahao.baidu.com/s?id=1758270917056241009&wfr=spider&for=pc
#
#
# - 技术局限性:
#
#     - 生成内容质量参差不齐，逻辑性、连贯性有待提高。
#
#     - 例如：文本生成可能出现语法错误、逻辑混乱等问题。
#
# - 人类创造力冲击:
#
#     - 生成式 AI 可能取代部分人类创意工作，引发就业问题。
#
#     - 例如：文案写作、平面设计等领域。
