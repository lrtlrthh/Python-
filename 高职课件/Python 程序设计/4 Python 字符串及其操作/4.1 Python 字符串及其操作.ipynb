# %% [markdown]
# # <span class="motutor-highlight motutor-id_l61cvvj-id_qqb4xmo"><i></i>Python 字符串及其操作 </span>

# %% [markdown]
# 字符串是 Python 中非常常用的数据类型。
# 在本节课程中，我们将学习 **字符串及字符串的相关操作** 的相关知识！

# %% [markdown]
# ## 1. 生成字符串
#
# **Python** 中可以使用一对单引号''或者双引号""生成字符串。

# %%
s = "hello world"
s

# %%
s = 'hello world'
s

# %% [markdown]
# 三引号用来输入包含多行文字的字符串：

# %%
s = """hello
world1"""
print (s)

s = '''hello
world2'''
print (s)

# %% [markdown]
# ## 2. 简单操作
#
# <img src="https://imgbed.momodel.cn/20200328210225.png" width=600/>

# %%
#字符串的加法：
s = "hello" + " world"
s

# %%
# 字符串与数字相乘：
"echo" * 3

# %%
# 字符串长度：
len(s)

# %% [markdown]
# ## 3. 字符串方法

# %% [markdown]
# **Python** 是一种面向对象的语言，面向对象的语言中一个必不可少的元素就是方法，而字符串是对象的一种，所以有很多可用的方法。
#
# 跟很多语言一样， **Python** 使用以下形式来调用方法：
#
#     对象.方法(参数)

# %% [markdown]
# ### 3.1 分割
#
# s.split() 将 s 按照空格（包括多个空格，制表符`\t`，换行符`\n`等）分割，并返回所有分割得到的字符串。

# %%
line = "1 2 3 4  5"
numbers = line.split()
print (numbers)

# %% [markdown]
# s.split(sep)以给定的 sep 为分隔符对 s 进行分割

# %%
line = "1,2,3,4,5"
numbers = line.split(',')
print (numbers)

# %% [markdown]
# ### 3.2 <span class="motutor-highlight motutor-id_xusxlaz-id_goatnqe"><i></i>连接</span>
#
# 与分割相反，s.join(str_sequence) 的作用是以 s 为连接符将字符串序列 str_sequence 中的元素连接起来，并返回连接后得到的新字符串：

# %%
s = ' '
s.join(numbers)

# %%
s = ','
s.join(numbers)

# %% [markdown]
# ### 3.3 替换
#
# s.replace(part1, part2) 将字符串 s 中指定的部分 part1 替换成想要的部分 part2 ，并返回新的字符串。

# %%
s = "hello world"
s.replace('world', 'python')
s

# %% [markdown]
# 此时，s 的值并没有变化，替换方法只是生成了一个新的字符串。

# %% [markdown]
# ### 3.4 大小写转换
#
# s.upper()方法返回一个将 s 中的字母全部大写的新字符串。
#
# s.lower()方法返回一个将 s 中的字母全部小写的新字符串。

# %%
"hello world".upper()

# %%
s = "HELLO WORLD"
print (s.lower())
print (s)

# %% [markdown]
# ### 3.5 去除多余空格
#
# s.strip()返回一个将 s 两端的多余空格除去的新字符串。
#
# s.lstrip()返回一个将 s 开头的多余空格除去的新字符串。
#
# s.rstrip()返回一个将 s 结尾的多余空格除去的新字符串。

# %%
s = "  hello world   "
s.strip()

# %% [markdown]
# s的值依然不会变化：

# %%
s

# %%
s.lstrip()

# %%
s.rstrip()

# %% [markdown]
# ### 3.6 更多方法
# 可以使用`dir`函数查看所有可以使用的方法：

# %%
dir(s)

# %% [markdown]
# ### 3.7 多行字符串
# Python 用一对 `"""` 或者 `'''` 来生成多行字符串：

# %%
a = """hello world.
it is a nice day."""
print (a)

# %% [markdown]
# 在储存时，在两行字符间会加上一个换行符 `'\n'`

# %%
a

# %% [markdown]
# 当代码太长或者为了美观起见时，我们可以使用两种方法来将一行代码转为多行代码：
#
# * ()
# * \

# %%
a = ("hello, world. "
    "it's a nice day. "
    "my name is xxx")
a

# %%
a = "hello, world. " \
    "it's a nice day. " \
    "my name is xxx"
a

# %% [markdown]
# ### 3.8 强制转换为字符串
# * `str(ob)`强制将`ob`转化成字符串。
# * `repr(ob)`也是强制将`ob`转化成字符串。
#
# 不同点如下：

# %%
# str() 给人看
s = "hello \n world"
print(str(s))

# %%
# repr() 给机器看
print(repr(s))

# %% [markdown]
# ### 3.9 整数与不同进制的字符串的转化

# %%
可以将整数按照不同进制转化为不同类型的字符串。

# %%
hex(255) #十六进制

# %%
oct(255) #八进制

# %%
bin(255) #二进制

# %% [markdown]
# 可以使用 `int` 将字符串转为整数：

# %%
int('23')

# %%
还可以指定按照多少进制来进行转换，最后返回十进制表达的整数：

# %%
int('FF', 16) #十六进制

# %%
int('377', 8) #八进制

# %%
int('11111111', 2) #二进制

# %% [markdown]
# `float` 可以将字符串转换为浮点数：

# %%
print(type(float('3.5')))

# %% [markdown]
# ### 3.10 格式化字符串
# **Python** 用字符串的`format()`方法来格式化字符串。
#
# 具体用法如下，字符串中花括号 `{}` 的部分会被 format 传入的参数替代，传入的值可以是字符串，也可以是数字或者别的对象。

# %%
'{} {} {}'.format('a', 'b', 'c')

# %% [markdown]
# 可以用数字指定传入参数的相对位置：

# %%
'{2} {1} {0}'.format('a', 'b', 'c')

# %% [markdown]
# 还可以指定传入参数的名称：

# %%
'{color} {n} {x}'.format(n=10, x=1.5, color='blue')

# %% [markdown]
# 可以在一起混用：

# %%
'{color} {0} {x} {1}'.format(10, 'foo', x = 1.5, color='blue')

# %% [markdown]
# 可以用`{<field name>:<format>}`指定格式：
# 模板里 {序号:格式} 的意思：
# {0:10} 第 0 个元素 'foo' 占 10 个字符宽；
# {1:10d} 第 1 个元素 5 按整数显示，占 10 格；
# {2:10.2f} 第 2 个元素 2*pi 按浮点数保留 2 位小数，占 10 格。

# %%
from math import pi

'{0:10} {1:10d} {2:10.2f}'.format('foo', 5, 2 * pi)

# %% [markdown]
# 也可以使用旧式的 `%` 方法进行格式化：

# %%
s = "some numbers:"
x = 1.34
y = 2
# 用百分号隔开，括号括起来
t = "%s %f, %d" % (s, x, y)
t

# %% [markdown]
# ## 4. 索引和分片

# %% [markdown]
# ### <span class="motutor-highlight motutor-id_4qz33yk-id_gm8ybnn"><i></i>4.1 索引</span>
#
# 对于一个有序序列，可以通过索引的方法来访问对应位置的值。字符串便是一个有序序列，**Python** 使用 **下标** 来对有序序列进行索引。索引是从 `0` 开始的，所以索引 `0` 对应与序列的第 `1` 个元素。

# %%
s = "12345"
s[0]

# %% [markdown]
# 除了正向索引，Python还引入了负索引值的用法，即从后向前开始计数，例如，索引 -2 表示倒数第 2 个元素：

# %%
s = "12345"
s[-2]

# %% [markdown]
# 单个索引大于等于字符串的长度时，会报错：

# %%
s = "12345"
s[6]

# %% [markdown]
# ### <span class="motutor-highlight motutor-id_o8aqgc5-id_b9mb54n"><i></i>4.2 分片</span>
#
# 分片用来从序列中提取出想要的子序列，其用法为：
#
#     var[lower:upper:step]
#
# 其范围包括 `lower` ，但不包括 `upper` ，即 `[lower, upper)`， `step` 表示取值间隔大小，如果没有默认为`1`。

# %%
s = "12345"
s[1:3]

# %% [markdown]
# 分片中包含的元素的个数为 `3-1=2` 。

# %% [markdown]
# 也可以使用负索引来指定分片的范围：

# %%
s[1:-2]

# %% [markdown]
# 包括索引 `1` 但是不包括索引 `-2` 。
#
# lower 和 upper 可以省略，省略 lower 意味着从开头开始分片，省略 upper 意味着一直分片到结尾。

# %%
s[:3] #省略lower

# %%
s[-3:] #省略upper

# %%
s[:] #都省略

# %% [markdown]
# 每隔两个取一个值：

# %%
s[::2]

# %% [markdown]
# 当 step 的值为负时，省略 lower 意味着从结尾开始分片，省略 upper 意味着一直分片到开头。

# %%
s[::-1]

# %% [markdown]
# 当给定的 upper 超出字符串的长度（注意：因为不包含 upper，所以可以等于）时，Python 并不会报错，不过只会计算到结尾。

# %%
s[:100]

# %% [markdown]
# ### 4.3 使用“0”作为索引开头的原因

# %% [markdown]
# #### 4.3.1 使用`[low, up)`形式的原因
# 假设需要表示字符串 `hello` 中的内部子串 `el` ：
#
# |方式|`[low, up)`|`(low, up]`|`(lower, upper)`|`[lower, upper]`
# |--|--|--|--|--|
# |表示|`[1,3)`|`(0,2]`|`(0,3)`|`[1,2]`
# |序列长度|`up - low`|`up - low`|`up - low - 1`|`up - low + 1`
#
# 对长度来说，前两种方式比较好，因为不需要烦人的加一减一。
#
# 现在只考虑前两种方法，假设要表示字符串`hello`中的从头开始的子串`hel`：
#
# |方式|`[low, up)`|`(low, up]`
# |--|--|
# |表示|`[0,3)`|`(-1,2]`|
# |序列长度|`up - low`|`up - low`|
#
# 第二种表示方法从`-1`开始，不是很好，所以选择使用第一种`[low, up)`的形式。

# %% [markdown]
# #### 4.3.2 使用 0-base 的形式
# 两种简单的情况：
#
# - 从头开始的n个元素；
#     - 使用0-base：`[0, n)`
#     - 使用1-base：`[1, n+1)`
#
# - 第`i+1`个元素到第`i+n`个元素。
#     - 使用0-base：`[i, n+i)`
#     - 使用1-base：`[i+1, n+i+1)`
#
# 1-base有个`+1`部分，所以不推荐。
#
# 综合这两种原因，**Python**使用 0-base 的方法来进行索引。
