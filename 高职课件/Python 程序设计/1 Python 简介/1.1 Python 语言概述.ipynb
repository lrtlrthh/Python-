# %% [markdown]
# # Python 语言概述

# %% [markdown]
# ## 1. Python 简介
#
# `Python`（英式发音：/ˈpaɪθən/；美式发音：/ˈpaɪθɑːn/）是由荷兰人吉多·范罗苏姆（Guido von Rossum）发明的一种编程语言，是目前世界上最受欢迎和拥有最多用户群体的编程语言。
#
# `Python` 强调代码的可读性和语法的简洁性，相较于 `C` 或 `Java`，`Python` 让使用者能够用更少的代码表达自己的意图。下面是 `TIOBE Index` 提供权威的编程语言排行榜给出的 `Python` 语言的排名，最近的两年时间 `Python` 语言都处于冠军的位置。
#
# <center>
# <img src="https://imgbed.momodel.cn/fangj_tiobe_index_top.png" width=1000 />
# </center>

# %% [markdown]
# ## 2. Python 的编年史
#
# - **1989年12月：** 吉多·范罗苏姆决心开发一个新的脚本语言及其解释器来打发无聊的圣诞节。这种语言将作为 `ABC` 语言的继承者，主要用来替代 `Unix shell` 和 `C` 语言实现系统管理。由于吉多本人是 BBC 电视剧《Monty Python's Flying Circus》的忠实粉丝，所以他选择了 `Python` 这个词作为新语言的名字。
#
# - **1991年02月：** 吉多·范罗苏姆在 alt.sources 新闻组上发布了 `Python 解释器`的最初代码，标记为版本 `0.9.0`。
#
# - **1994年01月：** `Python 1.0`发布，梦开始的地方。
#
# - **2000年10月：** `Python 2.0`发布，`Python` 的整个开发过程更加透明，生态圈开始慢慢形成。
#
# - **2008年12月：** `Python 3.0`发布，引入了诸多现代编程语言的新特性，但并不完全向下兼容。
#
# - **2011年04月：** `pip` 首次发布，`Python` 语言有了自己的包管理工具。
#
# - **2018年07月：** 吉多·范罗苏姆宣布从“终身仁慈独裁者”（开源项目社区出现争议时拥有最终决定权的人）的职位上“永久休假”。
#
# - **2020年01月：** 在 `Python 2`和 `Python 3`共存了11年之后，官方停止了对 `Python 2`的更新和维护，希望用户尽快切换到 `Python 3`。
#
# >**说明：** 大多数软件的版本号一般分为三段，形如 A.B.C，其中 A 表示大版本号，当软件整体重写升级或出现不向后兼容的改变时，才会增加 A；B 表示功能更新，出现新功能时增加 B；C 表示小的改动（例如：修复了某个 Bug ），只要有修改就增加 C。

# %% [markdown]
# ## 3. Python 的特点
#
# - **易于学习：**
#
#     `Python` 的语法简洁且自然，格式规范化，选择了自然的英文词作为其关键字，容易理解和编写。
#
# <center>
#  <img src="https://imgbed.momodel.cn/fangj_code_diff.png" width=1000 />
# </center>

# %% [markdown]
# - **功能强大：**
#
#     提供对数据分析、编写网络应用程序和实现机器学习之类的强大支持，超过万种应用场景，包括自动化、模拟和统计分析等。
#
# <center>
#  <img src="https://imgbed.momodel.cn/fangj_py_funtions.png" width=1000 />
# </center>

# %% [markdown]
# - **跨平台：**
#
#     可在 `Windows`、`macOS` 和 `Linux` 等不同平台上运行，并与多数应用具有良好的兼容性。
#
# <center>
#     <img src="https://imgbed.momodel.cn/fangj_cross_platform.png" width=1000 />
# </center>

# %% [markdown]
# - **应用范围广：**
#
#     适用于程序开发、数据科学、网络开发和科学研究等领域，并持续拓展其在最新技术中的应用
#
# <center>
#   <img src="https://imgbed.momodel.cn/fangj_apply_domian.png" width=1000 />
# </center>

# %% [markdown]
# ## 4. Python 的应用领域
#
# `Python` 的应用极其广泛，以下列举了一些主要领域及其代表性应用：

# %% [markdown]
# - **数据分析与可视化：** 使用 `pandas` 和 `numpy` 处理和分析大规模数据，结合 `matplotlib` 和 `seaborn` 进行数据可视化。
#
# <center>
# <img src="https://imgbed.momodel.cn/fangj_data_vision1.gif" width=1000 />
# </center>

# %% [markdown]
# - **机器学习与人工智能：** 利用 `scikit-learn`、`TensorFlow` 和 `PyTorch` 构建智能模型，进行图像识别、自然语言处理等任务。
#
# <center>
# <img src="https://imgbed.momodel.cn/fangj_ai_hand_1.gif" width=1000 />
# </center>
#
# <center>
# <img src="https://imgbed.momodel.cn/fangj_ai_hand_2.gif" width=1000 />
# </center>

# %% [markdown]
# - **`Web` 开发：** 使用 `Django` 或 `Flask` 快速构建功能全面的动态网站。
#
#     - `Django` 是一个“大而全”的框架，提供了许多内置功能，适合快速开发大型复杂项目；
#
#     - `Flask` 则是一个“小而精”的框架，更加轻量级和灵活，适合小型项目或需要高度定制的项目；

# %% [markdown]
# - **自动化脚本：** 编写小型脚本实现文件管理、数据爬取和任务调度等。例如全网自动爬取和批量打包下载想要的公开资源，如下图电影资源：
#
# <center>
# <img src="https://imgbed.momodel.cn/fangj_python_script.gif" width=1000 />
# </center>

# %% [markdown]
# - **科学计算：** 结合 `SciPy` 和 `SymPy` 解决复杂的数学问题。例如在物理或工程问题中，你可能需要先用 `SymPy` 建立模型，推导出公式，然后使用 `SciPy` 对模型进行数值模拟或分析，如下图模拟地球大气层变化：
#
# <center>
# <img src="https://imgbed.momodel.cn/fangj_earth’s atmosphere.gif" width=1000 />
# </center>
